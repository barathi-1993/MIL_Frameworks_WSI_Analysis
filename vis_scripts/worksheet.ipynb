# %%
import os
from pathlib import Path

folder_path = "/data_64T_3/Raja/MUFASA/2.Attention_Analysis/3.Groud_truth/Verified_final/CAMELYON16"

files = [f for f in os.listdir(folder_path)
         if os.path.isfile(os.path.join(folder_path, f))]

files.sort()

print(f"Found {len(files)} files in: {folder_path}\n")
for i, f in enumerate(files, 1):
    print(f"{i:>4}.  {f}")
# Out:
# Found 11 files in: /data_64T_3/Raja/MUFASA/2.Attention_Analysis/3.Groud_truth/Verified_final/CAMELYON16
#
#    1.  test_011_index.csv
#    2.  test_021_index.csv
#    3.  test_026_index.csv
#    4.  test_065_index.csv
#    5.  test_068_index.csv
#    6.  test_090_index.csv
#    7.  test_102_index.csv
#    8.  test_108_index.csv
#    9.  test_116_index.csv
#   10.  test_117_index.csv
#   11.  test_121_index.csv

# %%
from pathlib import Path

file_path = "/data_64T_3/Raja/MUFASA/2.Attention_Analysis/4.Results_and_plots/1.Extracted_Features_Coordinates_for_Test_WSI/CLAM/Extracted_features/resnet50_1024/test_117.pt"

if Path(file_path).exists():
    print(f"Found: {file_path}")
else:
    print(f"Not found: {file_path}")
# Out:
# Found: /data_64T_3/Raja/MUFASA/2.Attention_Analysis/4.Results_and_plots/1.Extracted_Features_Coordinates_for_Test_WSI/CLAM/Extracted_features/resnet50_1024/test_117.pt
